# %% [markdown]
# Two Sum
# https://leetcode.com/problems/two-sum/
#
# Best Time to Buy and Sell Stock
# https://leetcode.com/problems/best-time-to-buy-and-sell-stock/
#
# Contains Duplicate
# https://leetcode.com/problems/contains-duplicate/
#
# Product of Array Except Self
# https://leetcode.com/problems/product-of-array-except-self/
#
# Maximum Subarray
# https://leetcode.com/problems/maximum-subarray/
#
# Maximum Product Subarray
# https://leetcode.com/problems/maximum-product-subarray/
#
# Find Minimum in Rotated Sorted Array
# https://leetcode.com/problems/find-minimum-in-rotated-sorted-array/
#
# Search in Rotated Sorted Array
# https://leetcode.com/problems/search-in-rotated-sorted-array/
#
# 3Sum
# https://leetcode.com/problems/3sum/
#
# Container With Most Water
# https://leetcode.com/problems/container-with-most-water/

# %%
nums = [2,3,-1,4]
for i in range(len(nums)):
    curprod = nums[i]
    for j in range(i + 1, len(nums)):
        print(f"{nums[i]} ====> {nums[j]}")
        curprod *= nums[j]
    print(curprod)
# Out:
# 2 ====> 3
# 2 ====> -1
# 2 ====> 4
# -24
# 3 ====> -1
# 3 ====> 4
# -12
# -1 ====> 4
# -4
# 4

# %% [markdown]
# # 1. Two Sum

# %%
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """
        hashMap = {}
        for i, n in enumerate(nums):
            diff = target - n
            if diff in hashMap:
                return(hashMap[diff], i)
            hashMap[n] = i
        return
nums = [2, 7, 11, 15]
target = 9
sobj = Solution()
print(sobj.twoSum(nums, target))
# Out:
# (0, 1)

# %% [markdown]
# # 2. Best Time to Buy and Sell Stock
#
# You are given an array prices where prices[i] is the price of a given stock on the ith day.

# %%
from typing import List
def maxProfit(prices: List[int]) -> int:
    min_price = float('inf') #set to infinity initially
    max_profit = 0

    for price in prices:
        if price < min_price:
            min_price = price
        else:
            max_profit = max(max_profit, price - min_price)
    return max_profit 
prices = [7,1,5,3,6,4]
print(maxProfit(prices))
# Out:
# 5

# %% [markdown]
# # 3. 217 Contains Duplicate
# If we ever see a number that’s already in the set, we’ve found a duplicate.
#
# No need to scan the array multiple times.

# %%
def ContainsDuplicate(nums: List[int]) -> bool:
    seen = set()
    for num in nums:
        if num in seen:
            return True
        seen.add(num)
    return False

nums = [1,2,3,1]
ContainsDuplicate(nums)
# Out:
# True

# %% [markdown]
# # 4. 238. Product of Array Except Self
#
# Precompute prefix products (left side)
#
# Precompute suffix products (right side)
# 🔹 Approach
#
# Create an output array answer initialized with 1
#
# Traverse from left to right:
#
# answer[i] stores product of all elements before i
#
# Traverse from right to left:
#
# Multiply answer[i] by product of all elements after i
#
# Return answer

# %%
def productExceptSelf(nums: List[int]) -> List[int]:
    res = [1] * (len(nums))
    prefix = 1

    for i in range(len(nums)):
        res[i] = prefix
        prefix *= nums[i]
    
    postfix = 1

    for i in range(len(nums)-1, -1, -1):
        res[i] *= postfix
        postfix *= nums[i]
    
    return res

nums = [1,2,3,4]
print(productExceptSelf(nums))
# Out:
# [24, 12, 8, 6]

# %% [markdown]
# # 5. 53. Maximum Subarray
#
# Initialize:
#
# current_sum → sum of the best subarray ending at current index
#
# max_sum → overall maximum subarray sum
#
# Traverse the array:
#
# Update current_sum as the maximum of:
#
# current element alone
#
# current element + previous current_sum
#
# Update max_sum if current_sum is larger
#
# Return max_sum

# %%
def maxSubArray(nums: List[int]) -> int:
    maxSub = nums[0]
    curSum = 0

    for num in nums:
        if curSum < 0:
            curSum = 0

        curSum += num
        maxSub = max(maxSub, curSum)
    return maxSub

nums = [-2,1,-3,4,-1,2,1,-5,4]
maxSubArray(nums)
# Out:
# 6

# %% [markdown]
# # 6. 152. Maximum Product Subarray
#
# Approach
#
# Initialize:
#
# max_prod = nums[0] → max product so far
#
# min_prod = nums[0] → min product so far
#
# result = nums[0] → global max product
#
# Traverse the array from index 1:
#
# Temporarily store the old max_prod
#
# Update max_prod = max(current number, current × old max, current × old min)
#
# Update min_prod = min(current number, current × old max, current × old min)
#
# Update result = max(result, max_prod)
#
# Return result

# %%
## Maximum Subarray

nums = [2,3,-1,4]


def maxProduct(nums):
    n = len(nums)

    prefix = 1
    suffix = 1

    ans = float('-inf')

    for i in range(n):
        prefix *=nums[i]
        suffix *= nums[n -1 -i]

        ans = max(ans, prefix, suffix)

        if prefix == 0:
            prefix = 1
        if suffix == 0:
            suffix = 1
    return ans

print(maxProduct(nums))
# Out:
# 6

# %% [markdown]
# # 7 153. Find Minimum in Rotated Sorted Array
#
#
# 🔹 Intuition
#
# A sorted array is rotated. Example: [4,5,6,7,0,1,2]
#
# The minimum element is the only element where the previous element is bigger (or simply the pivot point).
#
# Because the array is mostly sorted, we can use binary search instead of linear scan → O(log n).
#
# 🔹 Approach
#
# Initialize left = 0, right = len(nums) - 1.
#
# While left < right:
#
# Find mid = (left + right) // 2
#
# Compare nums[mid] with nums[right]:
#
# If nums[mid] > nums[right] → minimum is in right half, set left = mid + 1
#
# Else → minimum is in left half including mid, set right = mid
#
# When loop ends, left == right → the minimum element.
#
# Key Insight:
#
# If mid > right → min is after mid
#
# Else → min is at mid or before

# %%
class Solution(object):
    def findMin(self, nums):
        left, right = 0, len(nums) - 1

        while left < right:
            mid = (left + right) // 2
            if nums[mid] > nums[right]:
                left = mid + 1
            else:
                right = mid

        return nums[left]
nums = [4, 5, 6, 7, 0, 1, 2]
sol = Solution()
print(sol.findMin(nums))
# Out:
# 0

# %% [markdown]
# # 8. Search in Rotated Sorted Array
#
#
# 🔹 Intuition
#
# We need to find a target in a rotated sorted array in O(log n) time.
#
# The array is mostly sorted, except for the rotation.
#
# Binary search still works if we figure out which half is sorted at each step:
#
# Check if the left half is sorted: nums[left] <= nums[mid]
#
# Otherwise, the right half is sorted.
#
# If the target lies within the sorted half, search there; else search the other half.
#
# 🔹 Approach
#
# Initialize left = 0 and right = len(nums) - 1
#
# While left <= right:
#
# Compute mid = (left + right) // 2
#
# If nums[mid] == target, return mid
#
# Check which half is sorted:
#
# Left half sorted (nums[left] <= nums[mid])
#
# If target is in [nums[left], nums[mid]], move right = mid - 1
#
# Else move left = mid + 1
#
# Right half sorted (nums[mid] < nums[right])
#
# If target is in [nums[mid], nums[right]], move left = mid + 1
#
# Else move right = mid - 1
#
# If not found, return -1

# %%
class Solution(object):
    def search(self, nums, target):
        left, right = 0, len(nums) - 1

        while left <= right:
            mid = (left + right) // 2

            if nums[mid] == target:
                return mid

            if nums[left] <= nums[mid]:  # Left half sorted
                if nums[left] <= target < nums[mid]:
                    right = mid - 1
                else:
                    left = mid + 1
            else:  # Right half sorted
                if nums[mid] < target <= nums[right]:
                    left = mid + 1
                else:
                    right = mid - 1

        return -1


if __name__ == "__main__":
    nums = [4,5,6,7,0,1,2]
    target = 0
    sol = Solution()
    print(sol.search(nums, target))
# Out:
# 4

# %%
# Out:
#   Cell In[13], line 4
#     🔹 Intuition
#     ^
# SyntaxError: invalid character '🔹' (U+1F539)

# %% [markdown]
# ### 128. Longest Consecutive Sequence

# %%
from typing import List
class Solution:
    def longestConsecutive(self, nums: List[int]) -> int:
        sor = sorted(nums)
        count = 1
        longest = 1
        print(sor)
        for i in range(1, len(sor)):
            if sor[i] == sor[i -1] + 1:
                count+=1
            
            elif sor[i] == sor[i -1]:
                continue

            else: 
                count = 1
            longest = max(longest, count)

        # print(longest)
        return longest



sobj = Solution()
nums = [100,4,200,1,3,2]
print(sobj.longestConsecutive(nums))
# Out:
# [1, 2, 3, 4, 100, 200]
# 4

# %% [markdown]
# #### 3. Longest Substring Without Repeating Characters

# %%
class Solution:
    def lengthOfLongestSubstring(self, s: str) -> int:
        char_index = {}
        start = max_len = 0

        for end in range(len(s)):
            if s[end] in char_index and char_index[s[end]] >= start:
                start = char_index[s[end]] + 1
            char_index[s[end]] = end
            max_len = max(max_len, end - start + 1)
        return max_len

s = "abcabcbb"
sobj = Solution()
sobj.lengthOfLongestSubstring(s)
# Out:
# 3

# %% [markdown]
# ### 647. Palindromic Substrings

# %%
class Solution:
    def countSubstrings(self, s: str) -> int:
        n = len(s)
        count = 0 

        for center in range(2 * n -1):
            left = center // 2
            right  = left + center % 2

            while left >= 0 and right < n and s[left] == s[right]:
                count += 1
                left -= 1
                right += 1
        
        return count

# %% [markdown]
# ### 133 Clone Graph

# %%
from typing import Optional
from collections import deque

class Node:
    def __init__(self, val=0, neighbors=None):
        self.val = val
        self.neighbors = neighbors if neighbors is not None else []

class Solution:
    def cloneGraph(self, node: Optional['Node']) -> Optional['Node']:
        if not node:
            return None

        visited = {}

        def dfs(current):
            if current in visited:
                return visited[current]

            clone = Node(current.val)
            visited[current] = clone

            for neighbor in current.neighbors:
                clone.neighbors.append(dfs(neighbor))

            return clone

        return dfs(node)

def build_graph(adj_list):
    if not adj_list:
        return None

    nodes = {}
    for i in range(1, len(adj_list) + 1):
        nodes[i] = Node(i)

    for i, neighbors in enumerate(adj_list, start=1):
        nodes[i].neighbors = [nodes[n] for n in neighbors]

    return nodes[1]

def print_graph(node):
    visited = set()
    queue = deque([node])

    while queue:
        curr = queue.popleft()
        if curr in visited:
            continue

        visited.add(curr)
        print(f"Node {curr.val}: {[n.val for n in curr.neighbors]}")

        for n in curr.neighbors:
            if n not in visited:
                queue.append(n)

# ---------- DRIVER CODE ----------
adj_list = [
    [2, 4],
    [1, 3],
    [2, 4],
    [1, 3]
]

original = build_graph(adj_list)

solution = Solution()
cloned = solution.cloneGraph(original)

print("Original Graph:")
print_graph(original)

print("\nCloned Graph:")
print_graph(cloned)

print("\nDeep Copy Check:")
print(original is cloned)
print(original.neighbors[0] is cloned.neighbors[0])
# Out:
# Original Graph:
# Node 1: [2, 4]
# Node 2: [1, 3]
# Node 4: [1, 3]
# Node 3: [2, 4]
#
# Cloned Graph:
# Node 1: [2, 4]
# Node 2: [1, 3]
# Node 4: [1, 3]
# Node 3: [2, 4]
#
# Deep Copy Check:
# False
# False

# %% [markdown]
# #### 647 Palindromic Substrings

# %%
from typing import List
class Solution:
    def longestPalindrome(self, s: str) -> str:
        if not s:
            return ""

        start = 0
        max_len = 1

        def expand(left, right):
            nonlocal start, max_len
            while left >= 0 and right < len(s) and s[left] == s[right]:
                current_len = right - left + 1
                if current_len > max_len:
                    max_len = current_len
                    start = left
                left -=1
                right +=1
                

        for i in range(len(s)):
            expand(i, i)       # Odd length palindrome
            expand(i, i + 1)   # Even length palindrome

        return s[start:start + max_len]



sobj = Solution()
# nums = [100,4,200,1,3,2]
st = "babad"
sobj.longestPalindrome(st)
# Out:
# 'bab'

# %% [markdown]
# ### 11. Container With Most Water

# %%
class Solution:
    def maxArea(self, heights: List[int]) -> int:
        res = 0
        l, r = 0, len(heights)-1

        while l < r:
            area = (r-l) * min(heights[l], heights[r])
            res = max(res, area)

            if heights[l] < heights[r]:
                l +=1
            else:
                r -=1
        return res
sobj = Solution()
height = [1,8,6,2,5,4,8,3,7]

sobj.maxArea(height)
# Out:
# 49

# %% [markdown]
# ### 139. Word Break

# %%
class Solution:
    def wordBreak(self, s: str, wordDict: List[str]) -> bool:
        n = len(s)
        word_set = set(wordDict)

        dp = [False] * (n+1)
        dp[n] = True

        for i in range(n -1, -1, -1):
            for word in word_set:
                length = len(word)
                if i + length <= n and s[i: i+length] == word:
                    if dp[i + length]:
                        dp[i] = True
                        break
        return dp[0]

sobj = Solution()
sobj.wordBreak(s = "leetcode", wordDict = ["leet","code"])
# Out:
# True

# %% [markdown]
# ### 141. Linked List Cycle

# %%
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution(object):
    def hasCycle(self, head):
        slow = head
        fast = head

        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

            if slow == fast:
                return True
        return False


# Helper function to build a linked list with a cycle
def build_linked_list(values, pos):
    if not values:
        return None

    nodes = [ListNode(v) for v in values]

    for i in range(len(nodes) - 1):
        nodes[i].next = nodes[i + 1]

    if pos != -1:
        nodes[-1].next = nodes[pos]

    return nodes[0]


# ✅ Correct input
sobj = Solution()
head = build_linked_list([3, 2, 0, -4], 1)
print(sobj.hasCycle(head))  # True
# Out:
# True

# %% [markdown]
# #### 268. Missing Number

# %%
class Solution:
    def missingNumber(self, nums: List[int]) -> int:
        n = len(nums)
        expected_sums = n * (n + 1)//2

        actual_sum = sum(nums)

        return expected_sums - actual_sum
nums = [3,0,1]
sobj = Solution()
sobj.missingNumber(nums)
# Out:
# 2

# %% [markdown]
# #### 15 3Sum

# %%
class Solution:
    def threeSum(self, nums: List[int]) -> List[List[int]]:
        res = []
        nums.sort()

        for i, a in enumerate(nums):
            if i > 0 and a == nums[i-1]:
                continue

            l, r = i + 1, len(nums) - 1

            while l < r:
                threeSum = a + nums[l] + nums[r]
                if threeSum > 0:
                    r -=1
                elif threeSum < 0:
                    l +=1
                else:
                    res.append([a, nums[l], nums[r]])
                    l +=1
                    while nums[l] == nums[l-1] and l<r:
                        l += 1
        return res
nums = [-1,0,1,2,-1,-4]

sobj = Solution()
sobj.threeSum(nums)
# Out:
# [[-1, -1, 2], [-1, 0, 1]]
