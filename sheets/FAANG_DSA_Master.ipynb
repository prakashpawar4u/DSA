# %% [markdown]
# # 🚀 FAANG DSA MASTER NOTEBOOK

# %% [markdown]
# # Sliding Window
#
# **Keywords:** contiguous, substring
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Longest Substring Without Repeating Characters](https://leetcode.com/problems/longest-substring-without-repeating-characters/) | Medium | Sliding Window | FAANG | expand/shrink window | High |
# | 2 | [Minimum Window Substring](https://leetcode.com/problems/minimum-window-substring/) | Hard | Sliding Window | FAANG | expand/shrink window | High |
# | 3 | [Permutation in String](https://leetcode.com/problems/permutation-in-string/) | Medium | Sliding Window | FAANG | expand/shrink window | High |
# | 4 | [Fruit Into Baskets](https://leetcode.com/problems/fruit-into-baskets/) | Medium | Sliding Window | FAANG | expand/shrink window | High |
# | 5 | [Max Consecutive Ones III](https://leetcode.com/problems/max-consecutive-ones-iii/) | Medium | Sliding Window | FAANG | expand/shrink window | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# def solve(nums):
#     left = 0
#     for right in range(len(nums)):
#         pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Two Pointers
#
# **Keywords:** sorted, left-right
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Container With Most Water](https://leetcode.com/problems/container-with-most-water/) | Medium | Two Pointers | FAANG | move inward | High |
# | 2 | [3Sum](https://leetcode.com/problems/3sum/) | Medium | Two Pointers | FAANG | move inward | High |
# | 3 | [Valid Palindrome](https://leetcode.com/problems/valid-palindrome/) | Easy | Two Pointers | FAANG | move inward | High |
# | 4 | [Two Sum II](https://leetcode.com/problems/two-sum-ii-input-array-is-sorted/) | Medium | Two Pointers | FAANG | move inward | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# def solve(arr):
#     l, r = 0, len(arr)-1
#     while l < r:
#         pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Binary Search
#
# **Keywords:** monotonic
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Binary Search](https://leetcode.com/problems/binary-search/) | Easy | Binary Search | FAANG | log n | High |
# | 2 | [Search Rotated Array](https://leetcode.com/problems/search-in-rotated-sorted-array/) | Medium | Binary Search | FAANG | log n | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# def solve(arr, target):
#     l, r = 0, len(arr)-1
#     while l <= r:
#         mid = (l+r)//2
#         pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Hashing + Prefix Sum
#
# **Keywords:** lookup, prefix
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Two Sum](https://leetcode.com/problems/two-sum/) | Easy | Prefix Sum | FAANG | hashmap usage | High |
# | 2 | [Subarray Sum Equals K](https://leetcode.com/problems/subarray-sum-equals-k/) | Medium | Prefix Sum | FAANG | hashmap usage | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# prefix = {0:1}
# cur = 0
# for x in nums:
#     cur += x
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Monotonic Stack
#
# **Keywords:** next greater
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Daily Temperatures](https://leetcode.com/problems/daily-temperatures/) | Medium | Stack | FAANG | maintain order | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# stack=[]
# for i,x in enumerate(nums):
#     pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Heap / Top K
#
# **Keywords:** priority
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Top K Frequent](https://leetcode.com/problems/top-k-frequent-elements/) | Medium | Heap | FAANG | k largest | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# import heapq
# heap=[]
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Intervals
#
# **Keywords:** merge
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Merge Intervals](https://leetcode.com/problems/merge-intervals/) | Medium | Intervals | FAANG | sort first | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# intervals.sort()
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # BFS
#
# **Keywords:** queue
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Level Order](https://leetcode.com/problems/binary-tree-level-order-traversal/) | Medium | BFS | FAANG | queue traversal | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# from collections import deque
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # DFS / Backtracking
#
# **Keywords:** recursion
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Subsets](https://leetcode.com/problems/subsets/) | Medium | DFS | FAANG | backtrack | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# def dfs():
#     pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Trees
#
# **Keywords:** recursion
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Max Depth](https://leetcode.com/problems/maximum-depth-of-binary-tree/) | Easy | Tree | FAANG | dfs | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# def dfs(root):
#     pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Linked List
#
# **Keywords:** pointer
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Reverse List](https://leetcode.com/problems/reverse-linked-list/) | Easy | LL | FAANG | pointer move | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# prev=None
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Union Find
#
# **Keywords:** DSU
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Number of Provinces](https://leetcode.com/problems/number-of-provinces/) | Medium | UF | FAANG | path compression | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# parent=list(range(n))
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Topological Sort
#
# **Keywords:** DAG
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Course Schedule](https://leetcode.com/problems/course-schedule/) | Medium | Topo | FAANG | indegree | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# from collections import deque
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Trie
#
# **Keywords:** prefix
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Implement Trie](https://leetcode.com/problems/implement-trie-prefix-tree/) | Medium | Trie | FAANG | prefix tree | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# class Trie:
#     pass
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Greedy
#
# **Keywords:** local optimal
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Jump Game](https://leetcode.com/problems/jump-game/) | Medium | Greedy | FAANG | max reach | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# max_reach=0
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # Dynamic Programming
#
# **Keywords:** state
#
# | No. | Problem | Difficulty | Pattern | Companies | Notes | FAANG Frequency |
# |----:|---------|------------|---------|-----------|-------|----------------|
# | 1 | [Climbing Stairs](https://leetcode.com/problems/climbing-stairs/) | Easy | DP | FAANG | bottom-up | High |
# | 2 | [Coin Change](https://leetcode.com/problems/coin-change/) | Medium | DP | FAANG | bottom-up | High |
#
# ---
#
# ## 🧩 Code Template
# ```python
# dp=[0]*(n+1)
# ```
#
# ---
#
# ## ✍️ Your Notes / Solution

# %% [markdown]
# # 📅 30-Day Roadmap
#
# - Day 1: Practice problems
# - Day 2: Practice problems
# - Day 3: Practice problems
# - Day 4: Practice problems
# - Day 5: Practice problems
# - Day 6: Practice problems
# - Day 7: Practice problems
# - Day 8: Practice problems
# - Day 9: Practice problems
# - Day 10: Practice problems
# - Day 11: Practice problems
# - Day 12: Practice problems
# - Day 13: Practice problems
# - Day 14: Practice problems
# - Day 15: Practice problems
# - Day 16: Practice problems
# - Day 17: Practice problems
# - Day 18: Practice problems
# - Day 19: Practice problems
# - Day 20: Practice problems
# - Day 21: Practice problems
# - Day 22: Practice problems
# - Day 23: Practice problems
# - Day 24: Practice problems
# - Day 25: Practice problems
# - Day 26: Practice problems
# - Day 27: Practice problems
# - Day 28: Practice problems
# - Day 29: Practice problems
# - Day 30: Practice problems
