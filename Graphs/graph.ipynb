# %% [markdown]
# # BFS Traversal
#
# BFS is a graph traversal algorithm that:
#
# Visits nodes level by level
#
# Uses a queue
#
# Is great for:
#
# Shortest path in unweighted graphs
#
# Level-order traversal
#
# Finding connected components
#
#
# Graph Representation (Adjacency List)
#
# We’ll use a dictionary where:
#
# Key → node
#
# Value → list of neighbors
# graph = {
#     0: [1, 2],
#     1: [0, 3, 4],
#     2: [0, 5],
#     3: [1],
#     4: [1],
#     5: [2]
# }

# %%
from collections import deque

from collections import deque

def bfs(graph, start):
    visited = set()
    queue = deque([start])

    visited.add(start)

    while queue:
        node = queue.popleft()
        print(node, end=" ")

        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                queue.append(neighbor)

# -------- Driver Code --------
if __name__ == "__main__":
    graph = {
        0: [1, 2],
        1: [0, 3, 4],
        2: [0, 5],
        3: [1],
        4: [1, 5],
        5: [2, 4]
    }

    start_node = 0
    print("BFS Traversal:")
    bfs(graph, start_node)
# Out:
# BFS Traversal:
# 0 1 2 3 4 5

# %% [markdown]
# ## DFS Traversal
#
# Depth First Search (DFS) is a graph traversal technique where:
#
# You go as deep as possible along one path before coming back and trying another path.
#
# ##### Think of it like exploring a maze:
#
# You pick a path
#
# Keep walking forward
#
# If you hit a dead end → you backtrack
#
# Then try a different path
#
#
# #### 🧠 Core Idea
#
# DFS follows this simple rule:
#
# Start from a node
#
# Mark it as visited
#
# Visit one unvisited neighbor
#
# Repeat step 2–3 for that neighbor
#
# When no unvisited neighbors remain → backtrack

# %%
def dfs(graph, start):
    visited = set()
    stack = [start]

    visited.add(start)

    while stack:
        node = stack.pop()
        print(node, end=" ")

        for neighbor in graph[node]:
            if neighbor not in visited:
                visited.add(neighbor)
                stack.append(neighbor)
