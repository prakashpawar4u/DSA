# %%
l = [10,20,30,40,50]

# %%
len(l)
# Out:
# 5

# %%
print(l[1:4])
# Out:
# [20, 30, 40]

# %%
l[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
l[-1]
# Out:
# 50

# %%
l.append(60)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(10 in l)
# Out:
# True

# %%
l.append(30)
print(l.count(30))
print(l.index(30))
# Out:
# 2
# 2

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60, 30]

# %%
print(l.index(30,4,7))
# Out:
# 6

# %%
l.remove(30)

# %%
l = [10, 20, 30, 40, 50, 60, 70, 80]
l.remove(15) # raises value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-784e67b4ce9a> in <module>
#       1 l = [10, 20, 30, 40, 50, 60, 70, 80]
# ----> 2 l.remove(15) # raises value error
#
# ValueError: list.remove(x): x not in list

# %%
l
# Out:
# [10, 20, 40, 50, 60, 30]
