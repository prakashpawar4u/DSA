# %%
l = [10,20,30,40,50]

# %%
len(l)
# Out:
# 5

# %%
print(l[1:4])
# Out:
# [20, 30, 40]

# %%
l[::-1]
# Out:
# [50, 40, 30, 20, 10]

# %%
l[-1]
# Out:
# 50

# %%
l.append(60)

# %%
l
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
print(10 in l)
# Out:
# True

# %%
l.append(30)
print(l.count(30))
print(l.index(30))
# Out:
# 2
# 2

# %%
print(l.index(30,4,7))
# Out:
# 6
